# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/2026_Fall_Application-Deployment/blob/main/Tasks/chinook_db_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
DB_URL = "https://github.com/lerocha/chinook-database/raw/master/ChinookDatabase/DataSources/Chinook_Sqlite.sqlite"
DB_PATH = "chinook.db"

# %%
import os
import requests

def download_chinook_db():
    if not os.path.exists(DB_PATH):
        print("📥 Downloading Chinook database...")
        response = requests.get(DB_URL)
        with open(DB_PATH, "wb") as f:
            f.write(response.content)
        print("✅ Download complete.")
    else:
        print("✅ Chinook DB already exists.")

download_chinook_db()
# Out:
# 📥 Downloading Chinook database...
# ✅ Download complete.

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect(DB_PATH)

# Get a list of all tables in the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Available tables in the database:", [table[0] for table in tables])
conn.close()
# Out:
# Available tables in the database: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']

# %%
import pandas as pd

# Read data from a table into a pandas DataFrame
# Replace 'albums' with one of the available table names listed above.
query = "SELECT * FROM Album"
df = pd.read_sql_query(query, conn)

# Close the connection
conn.close()

# Display the first few rows of the DataFrame
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /tmp/ipykernel_5937/195144817.py in <cell line: 0>()
#       4 # Replace 'albums' with one of the available table names listed above.
#       5 query = "SELECT * FROM Album"
# ----> 6 df = pd.read_sql_query(query, conn)
#       7
#       8 # Close the connection
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
# ...

# %%
import pandas as pd
import sqlite3

# Re-establish connection to the SQLite database
conn = sqlite3.connect(DB_PATH)

# Read data from a table into a pandas DataFrame
# Replace 'albums' with one of the available table names listed above.
query = "SELECT * FROM Album"
df = pd.read_sql_query(query, conn)

# Close the connection
conn.close()

# Display the first few rows of the DataFrame
df
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
# @title sqlite3.connect()를 with 구문에 직접 포함
import sqlite3

# Connect to the SQLite database
with sqlite3.connect('chinook.db') as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    print("Available tables in the database:", [table[0] for table in tables])
# Out:
# Available tables in the database: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database using a 'with' statement
with sqlite3.connect(DB_PATH) as conn:
    # Read data from the 'Album' table into a pandas DataFrame
    query = "SELECT * FROM Album"
    df_album = pd.read_sql_query(query, conn)

# Display the first few rows of the DataFrame
df_album
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
import sqlite3
import pandas as pd

# Initialize a dictionary to store all DataFrames
dfs = {}

# Connect to the SQLite database using a 'with' statement
with sqlite3.connect(DB_PATH) as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    # Iterate through each table and load it into a DataFrame
    for table_name in [table[0] for table in tables]:
        query = f"SELECT * FROM {table_name}"
        df = pd.read_sql_query(query, conn)
        dfs[table_name] = df
        print(f"--- {table_name} DataFrame head ---")
        display(df.head())
        print("\n")

print("All tables loaded into 'dfs' dictionary.")
# Out:
# --- Album DataFrame head ---
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3
# --- Artist DataFrame head ---
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains
# --- Customer DataFrame head ---
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# ...

# %%
dfs.keys()
# Out:
# dict_keys(['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track'])

# %%
dfs['Album']
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
def summarize_df(df: pd.DataFrame) -> pd.DataFrame:
    # 데이터프레임의 각 컬럼별 데이터 타입, 결측치 수/비율, 대표값 5개를 요약한 DataFrame을 반환합니다.
    summary_data = []
    for col in df.columns:
        dtype = df[col].dtype
        n_unique = df[col].nunique()
        null_cnt = df[col].isnull().sum()
        null_ratio = round((null_cnt / len(df)) * 100, 2)
        unique_vals = df[col].dropna().unique()
        sample_vals = list(unique_vals[:7])

        summary_data.append({
            'Column': col,
            'N_Unique': n_unique,
            'Dtype': dtype,
            'Null_Count': null_cnt,
            'Null_Ratio(%)': null_ratio,
            'Sample_Values_5': sample_vals
        })

    return pd.DataFrame(summary_data)

# %%
# Install the xlsxwriter library
# !pip install xlsxwriter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 4.6 MB/s eta 0:00:00
# ...

# %%
output_excel_path = 'all_tables_summary.xlsx'

# Create an Excel writer object
with pd.ExcelWriter(output_excel_path, engine='xlsxwriter') as writer:
    for table_name, df in dfs.items():
        print(f"Summarizing {table_name}...")
        summary_df = summarize_df(df)
        # Write each summary DataFrame to a separate sheet
        summary_df.to_excel(writer, sheet_name=table_name, index=False)
        print(f"Summary for {table_name} written to sheet '{table_name}'.")

print(f"All table summaries saved to '{output_excel_path}'")
# Out:
# Summarizing Album...
# Summary for Album written to sheet 'Album'.
# Summarizing Artist...
# Summary for Artist written to sheet 'Artist'.
# Summarizing Customer...
# Summary for Customer written to sheet 'Customer'.
# Summarizing Employee...
# Summary for Employee written to sheet 'Employee'.
# Summarizing Genre...
# Summary for Genre written to sheet 'Genre'.
# Summarizing Invoice...
# Summary for Invoice written to sheet 'Invoice'.
# Summarizing InvoiceLine...
# Summary for InvoiceLine written to sheet 'InvoiceLine'.
# Summarizing MediaType...
# Summary for MediaType written to sheet 'MediaType'.
# Summarizing Playlist...
# Summary for Playlist written to sheet 'Playlist'.
# Summarizing PlaylistTrack...
# Summary for PlaylistTrack written to sheet 'PlaylistTrack'.
# Summarizing Track...
# Summary for Track written to sheet 'Track'.
# All table summaries saved to 'all_tables_summary.xlsx'

# %%
from google.colab import files

# Download the generated Excel file
files.download('all_tables_summary.xlsx')
